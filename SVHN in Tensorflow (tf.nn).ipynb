# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# /Users/michal/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from datetime import datetime
from scipy.io import loadmat
from sklearn.utils import shuffle

# %%
def y_ohe(Y):
    ind = np.zeros((len(Y), len(set(Y))))
    for i in range(len(Y)):
        ind[i, Y[i]] = 1
    return ind

# %%
def error_rate(p, t):
    return np.mean(p != t)

# %%
def convpool(X, W, b):
    # assume pool size is 2x2 because we need to augment it with ls
    conv_out = tf.nn.conv2d(X, W, strides=[1,1,1,1], padding='SAME')
    conv_out = tf.nn.bias_add(conv_out, b)
    conv_act = tf.nn.relu(conv_out)
    pool_out = tf.nn.max_pool(
        conv_act, 
        ksize=[1,2,2,1], 
        strides=[1,2,2,1], 
        padding='SAME'
    )
    return pool_out

# %%
def init_filter(shape, poolsz):
    w = np.random.randn(*shape) / np.sqrt(np.prod(shape[:-1]) + shape[-1]*np.prod(shape[:-2] / np.prod(poolsz)))
    return w.astype(np.float32)

# %%
def rearrange(X):
    return (X.transpose(3, 0, 1, 2) / 255).astype(np.float32)

# %%
train = loadmat('../data/train_32x32.mat')
test = loadmat('../data/test_32x32.mat')

Xtrain = rearrange(train['X'])
Ytrain = train['y'].flatten() - 1

Xtrain, Ytrain = shuffle(Xtrain, Ytrain)
Ytrain_ind = y_ohe(Ytrain)

Xtest = rearrange(test['X'])
Ytest = test['y'].flatten() - 1

Ytest_ind = y_ohe(Ytest)

# %% [markdown]
# ## Visualize the data

# %%
for i in range(5):
    rand_num = np.random.randint(0, train['X'].shape[-1])
    label = train['y'][rand_num][0]
    plt.title('Label is {label}'.format(label=label))
    plt.imshow(train['X'][:,:,:,rand_num])
    plt.show()

# %%
max_iter = 10
print_period = 10
N = Xtrain.shape[0]
batch_sz = 500
n_batches = N // batch_sz

# %%
Xtrain = Xtrain[:73000,]
Ytrain = Ytrain[:73000]
Xtest = Xtest[:26000,]
Ytest = Ytest[:26000]
Ytest_ind = Ytest_ind[:26000,]

# %%
M = 500
K = 10
poolsz = (2,2)

# %%
W1_shape = (5,5,3,20)
W1_init = init_filter(W1_shape, poolsz)
b1_init = np.zeros(W1_shape[-1], dtype=np.float32)

W2_shape = (5,5,20,50)
W2_init = init_filter(W2_shape, poolsz)
b2_init = np.zeros(W2_shape[-1], dtype=np.float32)

W3_init = np.random.randn(W2_shape[-1]*8*8, M) / np.sqrt(W2_shape[-1]*8*8 + M)
b3_init = np.zeros(M, dtype=np.float32)

W4_init = np.random.randn(M, K) / np.sqrt(M + K)
b4_init = np.zeros(K, dtype=np.float32)

X = tf.placeholder(tf.float32, shape=(None, 32, 32, 3), name='X')
T = tf.placeholder(tf.float32, shape=(None, K), name='T')

W1 = tf.Variable(W1_init.astype(np.float32))
b1 = tf.Variable(b1_init.astype(np.float32))
W2 = tf.Variable(W2_init.astype(np.float32))
b2 = tf.Variable(b2_init.astype(np.float32))
W3 = tf.Variable(W3_init.astype(np.float32))
b3 = tf.Variable(b3_init.astype(np.float32))
W4 = tf.Variable(W4_init.astype(np.float32))
b4 = tf.Variable(b4_init.astype(np.float32))

Z1 = convpool(X, W1, b1)
Z2 = convpool(Z1, W2, b2)

Z2_shape = Z2.get_shape().as_list()

# reshape(what to reshape, [what dims])
Z2r = tf.reshape(Z2, [-1, np.prod(Z2_shape[1:])])

Z3 = tf.nn.relu(tf.matmul(Z2r, W3)+b3)
Yish = tf.matmul(Z3, W4) + b4

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=T, logits=Yish))
train_op = tf.train.RMSPropOptimizer(0.0001, decay=0.99, momentum=0.9).minimize(cost)

predict_op = tf.argmax(Yish, 1)

# %%
t0 = datetime.now()
LL = []
error = []
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)

    for i in range(max_iter):
        for j in range(n_batches):
            Xbatch = Xtrain[j*batch_sz:(j*batch_sz+batch_sz),]
            Ybatch = Ytrain_ind[j*batch_sz:(j*batch_sz+batch_sz),]

            if len(Xbatch) == batch_sz:
                sess.run(train_op, feed_dict={X: Xbatch, T: Ybatch})
                if j % print_period == 0:
                    test_cost = 0
                    prediction = np.zeros(len(Xtest))
                    for k in range(len(Xtest)//batch_sz):
                        Xtestbatch = Xtest[k*batch_sz:(k*batch_sz + batch_sz),]
                        Ytestbatch = Ytest_ind[k*batch_sz:(k*batch_sz + batch_sz),]
                        test_cost += sess.run(cost, feed_dict = {X: Xtestbatch, T: Ytestbatch})
                        prediction[k*batch_sz:(k*batch_sz + batch_sz)] = sess.run(predict_op, feed_dict={X: Xtestbatch})

                    err = error_rate(prediction, Ytest)
                    print('Cost/err at iteration: i={}, j={}: {:.3f}/{:.3f}'.format(i, j, test_cost, err))
                    LL.append(test_cost)
                    error.append(err)
print('Elapsed time: {}'.format(datetime.now() - t0))
# Out:
# Cost/err at iteration: i=0, j=0: 119.512/0.846
# Cost/err at iteration: i=0, j=10: 119.311/0.843
# Cost/err at iteration: i=0, j=20: 118.951/0.841
# Cost/err at iteration: i=0, j=30: 118.558/0.841
# Cost/err at iteration: i=0, j=40: 118.195/0.840
# Cost/err at iteration: i=0, j=50: 117.858/0.837
# Cost/err at iteration: i=0, j=60: 117.559/0.829
# Cost/err at iteration: i=0, j=70: 117.293/0.821
# Cost/err at iteration: i=0, j=80: 117.050/0.815
# Cost/err at iteration: i=0, j=90: 116.848/0.811
# Cost/err at iteration: i=0, j=100: 116.684/0.803
# Cost/err at iteration: i=0, j=110: 116.559/0.802
# Cost/err at iteration: i=0, j=120: 116.474/0.802
# Cost/err at iteration: i=0, j=130: 116.408/0.803
# Cost/err at iteration: i=0, j=140: 116.362/0.804
# Cost/err at iteration: i=1, j=0: 116.337/0.804
# Cost/err at iteration: i=1, j=10: 116.315/0.804
# Cost/err at iteration: i=1, j=20: 116.291/0.804
# Cost/err at iteration: i=1, j=30: 116.273/0.804
# Cost/err at iteration: i=1, j=40: 116.260/0.804
# Cost/err at iteration: i=1, j=50: 116.250/0.804
# Cost/err at iteration: i=1, j=60: 116.243/0.804
# Cost/err at iteration: i=1, j=70: 116.221/0.804
# Cost/err at iteration: i=1, j=80: 116.196/0.804
# Cost/err at iteration: i=1, j=90: 116.175/0.804
# Cost/err at iteration: i=1, j=100: 116.160/0.804
# Cost/err at iteration: i=1, j=110: 116.147/0.804
# Cost/err at iteration: i=1, j=120: 116.146/0.804
# Cost/err at iteration: i=1, j=130: 116.146/0.804
# Cost/err at iteration: i=1, j=140: 116.144/0.804
# Cost/err at iteration: i=2, j=0: 116.140/0.804
# Cost/err at iteration: i=2, j=10: 116.138/0.804
# Cost/err at iteration: i=2, j=20: 116.118/0.804
# Cost/err at iteration: i=2, j=30: 116.102/0.804
# Cost/err at iteration: i=2, j=40: 116.089/0.804
# Cost/err at iteration: i=2, j=50: 116.082/0.804
# Cost/err at iteration: i=2, j=60: 116.077/0.804
# Cost/err at iteration: i=2, j=70: 116.037/0.804
# Cost/err at iteration: i=2, j=80: 116.002/0.804
# Cost/err at iteration: i=2, j=90: 115.973/0.804
# Cost/err at iteration: i=2, j=100: 115.960/0.804
# Cost/err at iteration: i=2, j=110: 115.942/0.804
# Cost/err at iteration: i=2, j=120: 115.955/0.803
# Cost/err at iteration: i=2, j=130: 115.950/0.804
# Cost/err at iteration: i=2, j=140: 115.935/0.804
# Cost/err at iteration: i=3, j=0: 115.929/0.804
# Cost/err at iteration: i=3, j=10: 115.910/0.804
# Cost/err at iteration: i=3, j=20: 115.868/0.804
# Cost/err at iteration: i=3, j=30: 115.846/0.803
# Cost/err at iteration: i=3, j=40: 115.831/0.804
# Cost/err at iteration: i=3, j=50: 115.799/0.804
# Cost/err at iteration: i=3, j=60: 115.772/0.804
# Cost/err at iteration: i=3, j=70: 115.706/0.802
# Cost/err at iteration: i=3, j=80: 115.655/0.802
# Cost/err at iteration: i=3, j=90: 115.640/0.803
# Cost/err at iteration: i=3, j=100: 115.604/0.803
# Cost/err at iteration: i=3, j=110: 115.549/0.800
# Cost/err at iteration: i=3, j=120: 115.588/0.803
# Cost/err at iteration: i=3, j=130: 115.534/0.803
# Cost/err at iteration: i=3, j=140: 115.504/0.804
# Cost/err at iteration: i=4, j=0: 115.473/0.804
# Cost/err at iteration: i=4, j=10: 115.518/0.798
# Cost/err at iteration: i=4, j=20: 115.335/0.802
# Cost/err at iteration: i=4, j=30: 115.310/0.803
# Cost/err at iteration: i=4, j=40: 115.260/0.798
# Cost/err at iteration: i=4, j=50: 115.132/0.803
# Cost/err at iteration: i=4, j=60: 115.112/0.802
# Cost/err at iteration: i=4, j=70: 114.993/0.779
# Cost/err at iteration: i=4, j=80: 114.882/0.803
# Cost/err at iteration: i=4, j=90: 114.796/0.776
# Cost/err at iteration: i=4, j=100: 114.625/0.802
# Cost/err at iteration: i=4, j=110: 114.617/0.763
# Cost/err at iteration: i=4, j=120: 114.529/0.803
# Cost/err at iteration: i=4, j=130: 114.484/0.779
# Cost/err at iteration: i=4, j=140: 114.263/0.801
# Cost/err at iteration: i=5, j=0: 113.965/0.789
# Cost/err at iteration: i=5, j=10: 113.641/0.783
# Cost/err at iteration: i=5, j=20: 113.462/0.767
# Cost/err at iteration: i=5, j=30: 113.057/0.782
# Cost/err at iteration: i=5, j=40: 112.788/0.792
# Cost/err at iteration: i=5, j=50: 112.580/0.796
# Cost/err at iteration: i=5, j=60: 112.083/0.779
# Cost/err at iteration: i=5, j=70: 111.240/0.758
# Cost/err at iteration: i=5, j=80: 110.350/0.748
# Cost/err at iteration: i=5, j=90: 108.661/0.717
# Cost/err at iteration: i=5, j=100: 108.140/0.778
# Cost/err at iteration: i=5, j=110: 105.779/0.701
# Cost/err at iteration: i=5, j=120: 102.727/0.638
# Cost/err at iteration: i=5, j=130: 100.183/0.670
# Cost/err at iteration: i=5, j=140: 96.209/0.587
# Cost/err at iteration: i=6, j=0: 93.606/0.615
# Cost/err at iteration: i=6, j=10: 91.167/0.597
# Cost/err at iteration: i=6, j=20: 85.974/0.555
# Cost/err at iteration: i=6, j=30: 80.132/0.485
# Cost/err at iteration: i=6, j=40: 74.660/0.462
# Cost/err at iteration: i=6, j=50: 71.230/0.425
# Cost/err at iteration: i=6, j=60: 67.730/0.418
# Cost/err at iteration: i=6, j=70: 63.495/0.373
# Cost/err at iteration: i=6, j=80: 57.774/0.314
# Cost/err at iteration: i=6, j=90: 55.664/0.305
# Cost/err at iteration: i=6, j=100: 51.463/0.278
# Cost/err at iteration: i=6, j=110: 56.576/0.324
# Cost/err at iteration: i=6, j=120: 49.341/0.282
# Cost/err at iteration: i=6, j=130: 47.513/0.251
# Cost/err at iteration: i=6, j=140: 44.122/0.243
# Cost/err at iteration: i=7, j=0: 43.673/0.235
# Cost/err at iteration: i=7, j=10: 41.728/0.223
# Cost/err at iteration: i=7, j=20: 40.310/0.218
# Cost/err at iteration: i=7, j=30: 43.251/0.243
# Cost/err at iteration: i=7, j=40: 40.680/0.232
# Cost/err at iteration: i=7, j=50: 37.658/0.199
# Cost/err at iteration: i=7, j=60: 38.330/0.200
# Cost/err at iteration: i=7, j=70: 39.193/0.210
# Cost/err at iteration: i=7, j=80: 39.470/0.217
# Cost/err at iteration: i=7, j=90: 36.361/0.197
# Cost/err at iteration: i=7, j=100: 36.458/0.199
# Cost/err at iteration: i=7, j=110: 34.567/0.180
# Cost/err at iteration: i=7, j=120: 36.055/0.191
# Cost/err at iteration: i=7, j=130: 33.786/0.178
# Cost/err at iteration: i=7, j=140: 33.977/0.182
# Cost/err at iteration: i=8, j=0: 33.992/0.177
# Cost/err at iteration: i=8, j=10: 33.577/0.176
# Cost/err at iteration: i=8, j=20: 32.710/0.177
# Cost/err at iteration: i=8, j=30: 32.765/0.175
# Cost/err at iteration: i=8, j=40: 35.231/0.194
# Cost/err at iteration: i=8, j=50: 34.066/0.185
# Cost/err at iteration: i=8, j=60: 31.700/0.168
# Cost/err at iteration: i=8, j=70: 31.571/0.166
# Cost/err at iteration: i=8, j=80: 31.605/0.167
# Cost/err at iteration: i=8, j=90: 30.149/0.158
# Cost/err at iteration: i=8, j=100: 30.028/0.158
# Cost/err at iteration: i=8, j=110: 29.398/0.153
# Cost/err at iteration: i=8, j=120: 31.282/0.162
# Cost/err at iteration: i=8, j=130: 29.737/0.155
# Cost/err at iteration: i=8, j=140: 31.145/0.167
# Cost/err at iteration: i=9, j=0: 29.717/0.156
# Cost/err at iteration: i=9, j=10: 30.161/0.160
# Cost/err at iteration: i=9, j=20: 27.965/0.146
# Cost/err at iteration: i=9, j=30: 29.840/0.156
# Cost/err at iteration: i=9, j=40: 29.869/0.160
# Cost/err at iteration: i=9, j=50: 28.963/0.153
# Cost/err at iteration: i=9, j=60: 28.198/0.150
# Cost/err at iteration: i=9, j=70: 29.252/0.153
# Cost/err at iteration: i=9, j=80: 28.176/0.148
# Cost/err at iteration: i=9, j=90: 27.486/0.145
# Cost/err at iteration: i=9, j=100: 27.889/0.149
# Cost/err at iteration: i=9, j=110: 27.458/0.143
# Cost/err at iteration: i=9, j=120: 27.018/0.140
# Cost/err at iteration: i=9, j=130: 26.310/0.137
# Cost/err at iteration: i=9, j=140: 27.364/0.147
# Elapsed time: 3:18:15.178332

# %%
plt.plot(LL)
plt.show()

# %%
plt.plot(error)
plt.show()
