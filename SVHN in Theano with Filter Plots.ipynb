# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import theano
import theano.tensor as T

# %%
from theano.tensor.nnet import conv2d
from theano.tensor.signal import pool

# %%
from scipy.io import loadmat
from sklearn.utils import shuffle

# %%
from datetime import datetime

# %%
def error_rate(p, t):
    return np.mean(p!=t)

# %%
def relu(a):
    return a*(a>0)

# %%
def y2indicator(y):
    N = len(y)
    ind = np.zeros((N, 10))
    for i in range(N):
        ind[i, y[i]] = 1
    return ind

# %%
def conv_pool(X, W, b, poolsize=(2,2)):
    conv_out = conv2d(input=X, filters=W)
    pool_out = pool.pool_2d(
        input=conv_out,
        ws=poolsize,
        ignore_border=True
    )

    return relu(pool_out + b.dimshuffle('x', 0, 'x', 'x'))

# %%
def init_filter(shape, poolsz):
    w = np.random.randn(*shape) / np.sqrt(np.prod(shape[:-1]) + shape[-1]*np.prod(shape[:-2] / np.prod(poolsz)))
    return w.astype(np.float32)

# %%
def rearrange(X):
    return (X.transpose(3, 2, 0, 1) / 255).astype(np.float32)

# %%
train = loadmat('../data/train_32x32.mat')
test = loadmat('../data/test_32x32.mat')

Xtrain = rearrange(train['X'])
Ytrain = train['y'].flatten() - 1

Xtrain, Ytrain = shuffle(Xtrain, Ytrain)
Ytrain_ind = y2indicator(Ytrain)

Xtest = rearrange(test['X'])
Ytest = test['y'].flatten() - 1

Ytest_ind = y2indicator(Ytest)

# %% [markdown]
# ## Visualize some data

# %%
for i in range(5):
    rand_num = np.random.randint(0, train['X'].shape[-1])
    label = train['y'][rand_num][0]
    plt.title('Label is {label}'.format(label=label))
    plt.imshow(train['X'][:,:,:,rand_num])
    plt.show()

# %%
max_iter = 10
print_period = 10
lr = np.float32(0.00001)
reg = np.float32(0.01)
mu = np.float32(0.99)

# %%
N = Xtrain.shape[0]
batch_sz = 500
n_batch = N // batch_sz

# %%
M = 500
K = 10
poolsz = (2, 2)

# %%
W1_shape = (20, 3, 5, 5)
W1_init = init_filter(W1_shape, poolsz)
b1_init = np.zeros(W1_shape[0], dtype=np.float32)

W2_shape = (50, 20, 5, 5)
W2_init = init_filter(W2_shape, poolsz)
b2_init = np.zeros(W2_shape[0], dtype=np.float32)

W3_init = np.random.randn(W2_shape[0]*5*5, M) / np.sqrt(W2_shape[0]*5*5 + M)
b3_init = np.zeros(M, dtype=np.float32)

W4_init = np.random.randn(M, K) / np.sqrt(M + K)
b4_init = np.zeros(K, dtype=np.float32)

X = T.tensor4('X', dtype='float32')
Y = T.matrix('T')

# %%
W1 = theano.shared(W1_init, 'W1')
b1 = theano.shared(b1_init, 'b1')
W2 = theano.shared(W2_init, 'W2')
b2 = theano.shared(b2_init, 'b2')
W3 = theano.shared(W3_init.astype(np.float32), 'W3')
b3 = theano.shared(b3_init, 'b3')
W4 = theano.shared(W4_init.astype(np.float32), 'W4')
b4 = theano.shared(b4_init, 'b4')

dW1 = theano.shared(np.zeros(W1_init.shape, dtype=np.float32), 'dW1')
db1 = theano.shared(np.zeros(b1_init.shape, dtype=np.float32), 'db1')
dW2 = theano.shared(np.zeros(W2_init.shape, dtype=np.float32), 'dW2')
db2 = theano.shared(np.zeros(b2_init.shape, dtype=np.float32), 'db2')
dW3 = theano.shared(np.zeros(W3_init.shape, dtype=np.float32), 'dW3')
db3 = theano.shared(np.zeros(b3_init.shape, dtype=np.float32), 'db3')
dW4 = theano.shared(np.zeros(W4_init.shape, dtype=np.float32), 'dW4')
db4 = theano.shared(np.zeros(b4_init.shape, dtype=np.float32), 'db4')

# %%
Z1 = conv_pool(X, W1, b1)
Z2 = conv_pool(Z1, W2, b2)
Z3 = relu(Z2.flatten(ndim=2).dot(W3) + b3)
pY = T.nnet.softmax(Z3.dot(W4) + b4)

params = (W1, b1, W2, b2, W3, b3, W4, b4)
reg_cost = reg*np.sum((param*param).sum() for param in params)
cost = -(Y * T.log(pY)).sum() + reg_cost
prediction = T.argmax(pY, axis=1)

update_W1 = W1 + mu*dW1 - lr*T.grad(cost, W1)
update_b1 = b1 + mu*db1 - lr*T.grad(cost, b1)
update_W2 = W2 + mu*dW2 - lr*T.grad(cost, W2)
update_b2 = b2 + mu*db2 - lr*T.grad(cost, b2)
update_W3 = W3 + mu*dW3 - lr*T.grad(cost, W3)
update_b3 = b3 + mu*db3 - lr*T.grad(cost, b3)
update_W4 = W4 + mu*dW4 - lr*T.grad(cost, W4)
update_b4 = b4 + mu*db4 - lr*T.grad(cost, b4)

update_dW1 = mu*dW1 - lr*T.grad(cost, W1)
update_db1 = mu*db1 - lr*T.grad(cost, b1)
update_dW2 = mu*dW2 - lr*T.grad(cost, W2)
update_db2 = mu*db2 - lr*T.grad(cost, b2)
update_dW3 = mu*dW3 - lr*T.grad(cost, W3)
update_db3 = mu*db3 - lr*T.grad(cost, b3)
update_dW4 = mu*dW4 - lr*T.grad(cost, W4)
update_db4 = mu*db4 - lr*T.grad(cost, b4)

train = theano.function(
    inputs=[X, Y],
    updates=[
        (W1, update_W1),
        (b1, update_b1),
        (W2, update_W2),
        (b2, update_b2),
        (W3, update_W3),
        (b3, update_b3),
        (W4, update_W4),
        (b4, update_b4),
        (dW1, update_dW1),
        (db1, update_db1),
        (dW2, update_dW2),
        (db2, update_db2),
        (dW3, update_dW3),
        (db3, update_db3),
        (dW4, update_dW4),
        (db4, update_db4)
    ]
)

get_prediction = theano.function(
    inputs= [X,Y],
    outputs = [cost, prediction]
)

# %%
t0 = datetime.now()
LL = []
error = []
for i in range(max_iter):
#     Xtrain, Ytrain = shuffle(Xtrain, Ytrain)
    for j in range(n_batch):
        Xbatch = Xtrain[j*batch_sz:(j*batch_sz+batch_sz),]
        Ybatch = Ytrain_ind[j*batch_sz:(j*batch_sz+batch_sz),]

        train(Xbatch, Ybatch)
        if j % print_period == 0:
            cost_val, prediction_val = get_prediction(Xtest, Ytest_ind)
            err = error_rate(prediction_val, Ytest)
            print('Cost/err at iteration: i={}, j={}: {:.3f}/{:.3f}'.format(i,j,cost_val, err) )
            LL.append(cost_val)
            error.append(err)
print('Elapsed time: {}'.format(datetime.now() - t0))
# Out:
# Cost/err at iteration: i=0, j=0: 59683.832/0.857
# Cost/err at iteration: i=0, j=10: 58394.072/0.804
# Cost/err at iteration: i=0, j=20: 58662.602/0.804
# Cost/err at iteration: i=0, j=30: 58467.434/0.816
# Cost/err at iteration: i=0, j=40: 58514.097/0.804
# Cost/err at iteration: i=0, j=50: 58099.189/0.804
# Cost/err at iteration: i=0, j=60: 58001.780/0.804
# Cost/err at iteration: i=0, j=70: 58017.713/0.804
# Cost/err at iteration: i=0, j=80: 58011.724/0.804
# Cost/err at iteration: i=0, j=90: 57928.128/0.804
# Cost/err at iteration: i=0, j=100: 57897.248/0.804
# Cost/err at iteration: i=0, j=110: 57875.760/0.804
# Cost/err at iteration: i=0, j=120: 57862.330/0.804
# Cost/err at iteration: i=0, j=130: 57821.405/0.804
# Cost/err at iteration: i=0, j=140: 57759.809/0.804
# Cost/err at iteration: i=1, j=0: 57723.441/0.804
# Cost/err at iteration: i=1, j=10: 57676.376/0.804
# Cost/err at iteration: i=1, j=20: 57603.840/0.804
# Cost/err at iteration: i=1, j=30: 57460.497/0.802
# Cost/err at iteration: i=1, j=40: 57290.378/0.798
# Cost/err at iteration: i=1, j=50: 57024.427/0.788
# Cost/err at iteration: i=1, j=60: 56675.367/0.773
# Cost/err at iteration: i=1, j=70: 56084.081/0.779
# Cost/err at iteration: i=1, j=80: 55127.123/0.756
# Cost/err at iteration: i=1, j=90: 53666.663/0.716
# Cost/err at iteration: i=1, j=100: 51641.205/0.668
# Cost/err at iteration: i=1, j=110: 49206.747/0.638
# Cost/err at iteration: i=1, j=120: 47122.752/0.594
# Cost/err at iteration: i=1, j=130: 43628.883/0.544
# Cost/err at iteration: i=1, j=140: 41659.351/0.502
# Cost/err at iteration: i=2, j=0: 40967.236/0.495
# Cost/err at iteration: i=2, j=10: 37677.556/0.449
# Cost/err at iteration: i=2, j=20: 35820.058/0.425
# Cost/err at iteration: i=2, j=30: 33995.283/0.395
# Cost/err at iteration: i=2, j=40: 31648.463/0.366
# Cost/err at iteration: i=2, j=50: 30224.052/0.334
# Cost/err at iteration: i=2, j=60: 28465.768/0.327
# Cost/err at iteration: i=2, j=70: 26472.197/0.296
# Cost/err at iteration: i=2, j=80: 25270.670/0.284
# Cost/err at iteration: i=2, j=90: 24531.586/0.271
# Cost/err at iteration: i=2, j=100: 23374.457/0.255
# Cost/err at iteration: i=2, j=110: 23035.137/0.248
# Cost/err at iteration: i=2, j=120: 22724.806/0.247
# Cost/err at iteration: i=2, j=130: 22135.491/0.240
# Cost/err at iteration: i=2, j=140: 22170.042/0.237
# Cost/err at iteration: i=3, j=0: 21306.264/0.230
# Cost/err at iteration: i=3, j=10: 21182.459/0.228
# Cost/err at iteration: i=3, j=20: 20077.776/0.220
# Cost/err at iteration: i=3, j=30: 19434.430/0.206
# Cost/err at iteration: i=3, j=40: 18757.955/0.202
# Cost/err at iteration: i=3, j=50: 18230.899/0.195
# Cost/err at iteration: i=3, j=60: 18258.239/0.197
# Cost/err at iteration: i=3, j=70: 17996.761/0.199
# Cost/err at iteration: i=3, j=80: 16856.960/0.183
# Cost/err at iteration: i=3, j=90: 16907.861/0.184
# Cost/err at iteration: i=3, j=100: 16567.329/0.183
# Cost/err at iteration: i=3, j=110: 16938.193/0.190
# Cost/err at iteration: i=3, j=120: 15756.606/0.172
# Cost/err at iteration: i=3, j=130: 15405.849/0.167
# Cost/err at iteration: i=3, j=140: 14632.435/0.157
# Cost/err at iteration: i=4, j=0: 14587.514/0.158
# Cost/err at iteration: i=4, j=10: 15065.689/0.164
# Cost/err at iteration: i=4, j=20: 14538.435/0.157
# Cost/err at iteration: i=4, j=30: 14100.756/0.152
# Cost/err at iteration: i=4, j=40: 13934.432/0.149
# Cost/err at iteration: i=4, j=50: 13735.368/0.149
# Cost/err at iteration: i=4, j=60: 13777.153/0.151
# Cost/err at iteration: i=4, j=70: 13580.678/0.149
# Cost/err at iteration: i=4, j=80: 13118.336/0.144
# Cost/err at iteration: i=4, j=90: 12992.320/0.142
# Cost/err at iteration: i=4, j=100: 12897.081/0.141
# Cost/err at iteration: i=4, j=110: 12998.761/0.142
# Cost/err at iteration: i=4, j=120: 13104.017/0.144
# Cost/err at iteration: i=4, j=130: 12902.802/0.142
# Cost/err at iteration: i=4, j=140: 12610.467/0.137
# Cost/err at iteration: i=5, j=0: 12566.011/0.138
# Cost/err at iteration: i=5, j=10: 12459.894/0.136
# Cost/err at iteration: i=5, j=20: 12424.851/0.135
# Cost/err at iteration: i=5, j=30: 12189.117/0.134
# Cost/err at iteration: i=5, j=40: 12388.036/0.138
# Cost/err at iteration: i=5, j=50: 11893.439/0.131
# Cost/err at iteration: i=5, j=60: 11933.706/0.131
# Cost/err at iteration: i=5, j=70: 12069.582/0.133
# Cost/err at iteration: i=5, j=80: 12409.698/0.138
# Cost/err at iteration: i=5, j=90: 11965.434/0.133
# Cost/err at iteration: i=5, j=100: 11670.008/0.129
# Cost/err at iteration: i=5, j=110: 11564.512/0.127
# Cost/err at iteration: i=5, j=120: 11533.334/0.126
# Cost/err at iteration: i=5, j=130: 11976.119/0.131
# Cost/err at iteration: i=5, j=140: 11390.316/0.124
# Cost/err at iteration: i=6, j=0: 11587.391/0.124
# Cost/err at iteration: i=6, j=10: 11425.354/0.123
# Cost/err at iteration: i=6, j=20: 11689.306/0.127
# Cost/err at iteration: i=6, j=30: 11381.036/0.124
# Cost/err at iteration: i=6, j=40: 11162.259/0.120
# Cost/err at iteration: i=6, j=50: 11185.756/0.120
# Cost/err at iteration: i=6, j=60: 11075.223/0.120
# Cost/err at iteration: i=6, j=70: 11170.056/0.123
# Cost/err at iteration: i=6, j=80: 11145.213/0.120
# Cost/err at iteration: i=6, j=90: 11061.595/0.121
# Cost/err at iteration: i=6, j=100: 12054.101/0.130
# Cost/err at iteration: i=6, j=110: 11369.601/0.124
# Cost/err at iteration: i=6, j=120: 11398.447/0.124
# Cost/err at iteration: i=6, j=130: 11017.580/0.119
# Cost/err at iteration: i=6, j=140: 11232.154/0.120
# Cost/err at iteration: i=7, j=0: 11172.344/0.121
# Cost/err at iteration: i=7, j=10: 10967.353/0.116
# Cost/err at iteration: i=7, j=20: 10775.490/0.114
# Cost/err at iteration: i=7, j=30: 11261.325/0.120
# Cost/err at iteration: i=7, j=40: 11059.529/0.117
# Cost/err at iteration: i=7, j=50: 10920.838/0.113
# Cost/err at iteration: i=7, j=60: 11086.775/0.117
# Cost/err at iteration: i=7, j=70: 11086.010/0.117
# Cost/err at iteration: i=7, j=80: 11157.858/0.118
# Cost/err at iteration: i=7, j=90: 10942.985/0.115
# Cost/err at iteration: i=7, j=100: 10709.287/0.113
# Cost/err at iteration: i=7, j=110: 11916.206/0.130
# Cost/err at iteration: i=7, j=120: 11354.276/0.120
# Cost/err at iteration: i=7, j=130: 11755.015/0.126
# Cost/err at iteration: i=7, j=140: 10791.484/0.112
# Cost/err at iteration: i=8, j=0: 11140.558/0.118
# Cost/err at iteration: i=8, j=10: 11498.489/0.122
# Cost/err at iteration: i=8, j=20: 11077.046/0.115
# Cost/err at iteration: i=8, j=30: 11015.491/0.114
# Cost/err at iteration: i=8, j=40: 11171.871/0.117
# Cost/err at iteration: i=8, j=50: 11437.493/0.121
# Cost/err at iteration: i=8, j=60: 10999.618/0.116
# Cost/err at iteration: i=8, j=70: 11172.585/0.118
# Cost/err at iteration: i=8, j=80: 11098.527/0.114
# Cost/err at iteration: i=8, j=90: 10951.403/0.113
# Cost/err at iteration: i=8, j=100: 10887.665/0.114
# Cost/err at iteration: i=8, j=110: 11088.988/0.118
# Cost/err at iteration: i=8, j=120: 11453.968/0.118
# Cost/err at iteration: i=8, j=130: 11312.020/0.115
# Cost/err at iteration: i=8, j=140: 11111.634/0.115
# Cost/err at iteration: i=9, j=0: 11247.290/0.115
# Cost/err at iteration: i=9, j=10: 10929.173/0.114
# Cost/err at iteration: i=9, j=20: 11321.603/0.117
# Cost/err at iteration: i=9, j=30: 11179.931/0.115
# Cost/err at iteration: i=9, j=40: 11168.430/0.115
# Cost/err at iteration: i=9, j=50: 11649.129/0.118
# Cost/err at iteration: i=9, j=60: 11045.528/0.114
# Cost/err at iteration: i=9, j=70: 11296.440/0.118
# Cost/err at iteration: i=9, j=80: 11221.653/0.114
# Cost/err at iteration: i=9, j=90: 11203.443/0.118
# Cost/err at iteration: i=9, j=100: 11724.849/0.116
# Cost/err at iteration: i=9, j=110: 11185.193/0.114
# Cost/err at iteration: i=9, j=120: 11631.424/0.120
# Cost/err at iteration: i=9, j=130: 12096.648/0.120
# Cost/err at iteration: i=9, j=140: 11946.781/0.126
# Elapsed time: 0:40:31.839384

# %%
plt.plot(LL)
plt.show()

# %%
plt.plot(error)
plt.show()

# %%
# visualize 1
W1_val = W1.get_value()
grid = np.zeros((8*5, 8*5))
m = 0
n = 0
for i in range(20):
    for j in range(3):
        filt = W1_val[i, j]
        grid[m*5:(m+1)*5, n*5:(n+1)*5] = filt
        m += 1
        if m >= 8:
            m = 0
            n += 1
plt.imshow(grid, cmap='gray')
plt.title('W1')
plt.show()

# %%
# visualize 2
W2_val = W2.get_value()
grid = np.zeros((32*5, 32*5))
m = 0
n = 0
for i in range(50):
    for j in range(20):
        filt = W2_val[i, j]
        grid[m*5:(m+1)*5, n*5:(n+1)*5] = filt
        m += 1
        if m >= 32:
            m = 0
            n += 1
plt.imshow(grid, cmap='gray')
plt.title('W2')
plt.show()
